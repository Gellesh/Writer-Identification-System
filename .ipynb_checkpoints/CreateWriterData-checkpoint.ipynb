# %%
import os
import shutil
import random

# %%
metaDataForm = "forms.txt" 
file = open(metaDataForm, "r")
writer_dic = dict()

# %%
for line in file:
    if line.startswith("#"):
        continue
    try:
        x = line.split(" ")[:2]
        writer_dic[x[0]] = x[1]
        
    except:
        pass

# %%
training_dir = 'formsE-H'   # dataset folder
writer_dir = 'Writers'      # The writers folder 
entries = os.listdir(training_dir)
try:
    os.mkdir(writer_dir)
except FileExistsError as exc:
    pass

# %%
for entry in entries:
    image_name = entry.split(".")[:1]
    writer_id = writer_dic[image_name[0]]
    
    try:
        os.mkdir(os.path.join(writer_dir,writer_id))
    except FileExistsError as exc:
        pass
    src = os.path.join(training_dir, entry)
    dst = os.path.join(writer_dir, writer_id, entry)
    shutil.copy(src, dst)

# %%
# Walking a directory tree and printing the names of the directories and files
root = "Writers"
threCount = 0
for dirpath, dirnames, files in os.walk(os.path.join(root)):
    if dirpath == root :
        continue
#     print(f'Found directory: {dirpath}')
    count = 0
    for file_name in files:
        count += 1
    if count > 2:
        threCount += 1 
        print("Writer {} has {} Imgs \n".format(dirpath,count))

print(threCount)
# Out:
# Writer Writers\000 has 59 Imgs
#
# Writer Writers\013 has 3 Imgs
#
# Writer Writers\016 has 3 Imgs
#
# Writer Writers\017 has 3 Imgs
#
# Writer Writers\019 has 3 Imgs
#
# Writer Writers\025 has 5 Imgs
#
# Writer Writers\026 has 5 Imgs
#
# Writer Writers\037 has 5 Imgs
#
# Writer Writers\058 has 4 Imgs
#
# Writer Writers\059 has 4 Imgs
#
# Writer Writers\060 has 4 Imgs
#
# Writer Writers\061 has 4 Imgs
#
# Writer Writers\062 has 3 Imgs
#
# Writer Writers\063 has 3 Imgs
#
# Writer Writers\064 has 4 Imgs
#
# Writer Writers\085 has 6 Imgs
#
# Writer Writers\087 has 3 Imgs
#
# Writer Writers\088 has 3 Imgs
#
# Writer Writers\089 has 3 Imgs
#
# Writer Writers\090 has 3 Imgs
#
# Writer Writers\092 has 3 Imgs
#
# Writer Writers\093 has 3 Imgs
#
# Writer Writers\094 has 3 Imgs
#
# Writer Writers\107 has 4 Imgs
#
# Writer Writers\108 has 4 Imgs
#
# Writer Writers\109 has 4 Imgs
#
# Writer Writers\110 has 4 Imgs
#
# Writer Writers\111 has 4 Imgs
#
# Writer Writers\112 has 4 Imgs
#
# Writer Writers\113 has 4 Imgs
#
# Writer Writers\114 has 4 Imgs
#
# Writer Writers\117 has 4 Imgs
#
# Writer Writers\118 has 7 Imgs
#
# Writer Writers\123 has 5 Imgs
#
# Writer Writers\124 has 4 Imgs
#
# Writer Writers\125 has 5 Imgs
#
# Writer Writers\126 has 5 Imgs
#
# Writer Writers\127 has 3 Imgs
#
# Writer Writers\128 has 5 Imgs
#
# Writer Writers\129 has 4 Imgs
#
# Writer Writers\130 has 5 Imgs
#
# Writer Writers\131 has 4 Imgs
#
# Writer Writers\132 has 4 Imgs
#
# Writer Writers\133 has 5 Imgs
#
# Writer Writers\150 has 10 Imgs
#
# Writer Writers\151 has 10 Imgs
#
# Writer Writers\152 has 10 Imgs
#
# Writer Writers\153 has 10 Imgs
#
# Writer Writers\154 has 10 Imgs
#
# Writer Writers\155 has 9 Imgs
#
# Writer Writers\158 has 3 Imgs
#
# Writer Writers\173 has 5 Imgs
#
# Writer Writers\174 has 5 Imgs
#
# Writer Writers\181 has 3 Imgs
#
# Writer Writers\193 has 4 Imgs
#
# Writer Writers\199 has 4 Imgs
#
# Writer Writers\202 has 5 Imgs
#
# Writer Writers\203 has 5 Imgs
#
# Writer Writers\204 has 5 Imgs
#
# Writer Writers\205 has 5 Imgs
#
# Writer Writers\206 has 5 Imgs
#
# Writer Writers\207 has 5 Imgs
#
# Writer Writers\208 has 5 Imgs
#
# Writer Writers\209 has 7 Imgs
#
# Writer Writers\212 has 3 Imgs
#
# Writer Writers\213 has 3 Imgs
#
# Writer Writers\217 has 3 Imgs
#
# Writer Writers\239 has 3 Imgs
#
# Writer Writers\241 has 4 Imgs
#
# Writer Writers\242 has 3 Imgs
#
# Writer Writers\243 has 3 Imgs
#
# Writer Writers\246 has 4 Imgs
#
# Writer Writers\247 has 5 Imgs
#
# Writer Writers\248 has 5 Imgs
#
# Writer Writers\272 has 3 Imgs
#
# Writer Writers\273 has 5 Imgs
#
# Writer Writers\274 has 5 Imgs
#
# Writer Writers\285 has 5 Imgs
#
# Writer Writers\286 has 4 Imgs
#
# Writer Writers\287 has 5 Imgs
#
# Writer Writers\288 has 5 Imgs
#
# Writer Writers\289 has 5 Imgs
#
# Writer Writers\291 has 4 Imgs
#
# Writer Writers\292 has 5 Imgs
#
# Writer Writers\293 has 5 Imgs
#
# Writer Writers\294 has 4 Imgs
#
# Writer Writers\296 has 3 Imgs
#
# Writer Writers\297 has 3 Imgs
#
# Writer Writers\298 has 3 Imgs
#
# Writer Writers\299 has 3 Imgs
#
# Writer Writers\300 has 3 Imgs
#
# Writer Writers\330 has 4 Imgs
#
# Writer Writers\332 has 8 Imgs
#
# Writer Writers\333 has 9 Imgs
#
# Writer Writers\334 has 9 Imgs
#
# Writer Writers\335 has 8 Imgs
#
# Writer Writers\336 has 9 Imgs
#
# Writer Writers\337 has 9 Imgs
#
# Writer Writers\338 has 9 Imgs
#
# Writer Writers\339 has 9 Imgs
#
# Writer Writers\340 has 9 Imgs
#
# Writer Writers\341 has 9 Imgs
#
# Writer Writers\342 has 9 Imgs
#
# Writer Writers\343 has 9 Imgs
#
# Writer Writers\344 has 9 Imgs
#
# Writer Writers\345 has 9 Imgs
#
# Writer Writers\346 has 9 Imgs
#
# Writer Writers\347 has 9 Imgs
#
# Writer Writers\348 has 9 Imgs
#
# Writer Writers\349 has 9 Imgs
#
# Writer Writers\350 has 4 Imgs
#
# Writer Writers\351 has 5 Imgs
#
# Writer Writers\352 has 5 Imgs
#
# Writer Writers\353 has 5 Imgs
#
# Writer Writers\354 has 5 Imgs
#
# Writer Writers\355 has 5 Imgs
#
# Writer Writers\357 has 3 Imgs
#
# Writer Writers\384 has 6 Imgs
#
# Writer Writers\385 has 5 Imgs
#
# Writer Writers\386 has 5 Imgs
#
# Writer Writers\387 has 5 Imgs
#
# Writer Writers\388 has 3 Imgs
#
# Writer Writers\389 has 5 Imgs
#
# Writer Writers\390 has 5 Imgs
#
# Writer Writers\391 has 5 Imgs
#
# Writer Writers\392 has 4 Imgs
#
# 126

# %%
# Walking a directory tree and delete folders with less than 1 img
root = "Writers"
threCount = 0
for dirpath, dirnames, files in os.walk(os.path.join(root)):
    if dirpath == root :
        continue
#     print(f'Found directory: {dirpath}')
    count = 0
    for file_name in files:
        count += 1
    if count < 2:
        threCount += 1 
        print("Writer {} has {} Imgs \n".format(dirpath,count))
        try:
            shutil.rmtree(dirpath)
        except OSError as e:
            print(f'Error: {trash_dir} : {e.strerror}')

print(threCount)
# Out:
# Writer Writers\002 has 1 Imgs
#
# Writer Writers\004 has 1 Imgs
#
# Writer Writers\006 has 1 Imgs
#
# Writer Writers\015 has 1 Imgs
#
# Writer Writers\020 has 1 Imgs
#
# Writer Writers\021 has 1 Imgs
#
# Writer Writers\022 has 1 Imgs
#
# Writer Writers\023 has 1 Imgs
#
# Writer Writers\024 has 1 Imgs
#
# Writer Writers\027 has 1 Imgs
#
# Writer Writers\028 has 1 Imgs
#
# Writer Writers\029 has 1 Imgs
#
# Writer Writers\030 has 1 Imgs
#
# Writer Writers\031 has 1 Imgs
#
# Writer Writers\032 has 1 Imgs
#
# Writer Writers\033 has 1 Imgs
#
# Writer Writers\034 has 1 Imgs
#
# Writer Writers\035 has 1 Imgs
#
# Writer Writers\036 has 1 Imgs
#
# Writer Writers\038 has 1 Imgs
#
# Writer Writers\039 has 1 Imgs
#
# Writer Writers\040 has 1 Imgs
#
# Writer Writers\041 has 1 Imgs
#
# Writer Writers\042 has 1 Imgs
#
# Writer Writers\043 has 1 Imgs
#
# Writer Writers\044 has 1 Imgs
#
# Writer Writers\045 has 1 Imgs
#
# Writer Writers\046 has 1 Imgs
#
# Writer Writers\047 has 1 Imgs
#
# Writer Writers\048 has 1 Imgs
#
# Writer Writers\049 has 1 Imgs
#
# Writer Writers\050 has 1 Imgs
#
# Writer Writers\051 has 1 Imgs
#
# Writer Writers\052 has 1 Imgs
#
# Writer Writers\053 has 1 Imgs
#
# Writer Writers\054 has 1 Imgs
#
# Writer Writers\055 has 1 Imgs
#
# Writer Writers\056 has 1 Imgs
#
# Writer Writers\067 has 1 Imgs
#
# Writer Writers\068 has 1 Imgs
#
# Writer Writers\069 has 1 Imgs
#
# Writer Writers\070 has 1 Imgs
#
# Writer Writers\071 has 1 Imgs
#
# Writer Writers\072 has 1 Imgs
#
# Writer Writers\073 has 1 Imgs
#
# Writer Writers\074 has 1 Imgs
#
# Writer Writers\075 has 1 Imgs
#
# Writer Writers\076 has 1 Imgs
#
# Writer Writers\077 has 1 Imgs
#
# Writer Writers\078 has 1 Imgs
#
# Writer Writers\079 has 1 Imgs
#
# Writer Writers\080 has 1 Imgs
#
# Writer Writers\081 has 1 Imgs
#
# Writer Writers\082 has 1 Imgs
#
# Writer Writers\083 has 1 Imgs
#
# Writer Writers\086 has 1 Imgs
#
# Writer Writers\096 has 1 Imgs
#
# Writer Writers\097 has 1 Imgs
#
# Writer Writers\098 has 1 Imgs
#
# Writer Writers\099 has 1 Imgs
#
# Writer Writers\100 has 1 Imgs
#
# Writer Writers\103 has 1 Imgs
#
# Writer Writers\104 has 1 Imgs
#
# Writer Writers\105 has 1 Imgs
#
# Writer Writers\106 has 1 Imgs
#
# Writer Writers\115 has 1 Imgs
#
# Writer Writers\116 has 1 Imgs
#
# Writer Writers\120 has 1 Imgs
#
# Writer Writers\122 has 1 Imgs
#
# Writer Writers\136 has 1 Imgs
#
# Writer Writers\137 has 1 Imgs
#
# Writer Writers\138 has 1 Imgs
#
# Writer Writers\141 has 1 Imgs
#
# Writer Writers\142 has 1 Imgs
#
# Writer Writers\143 has 1 Imgs
#
# Writer Writers\144 has 1 Imgs
#
# Writer Writers\145 has 1 Imgs
#
# Writer Writers\146 has 1 Imgs
#
# Writer Writers\147 has 1 Imgs
#
# Writer Writers\148 has 1 Imgs
#
# Writer Writers\149 has 1 Imgs
#
# Writer Writers\156 has 1 Imgs
#
# Writer Writers\167 has 1 Imgs
#
# Writer Writers\176 has 1 Imgs
#
# Writer Writers\182 has 1 Imgs
#
# Writer Writers\183 has 1 Imgs
#
# Writer Writers\189 has 1 Imgs
#
# Writer Writers\191 has 1 Imgs
#
# Writer Writers\196 has 1 Imgs
#
# Writer Writers\200 has 1 Imgs
#
# Writer Writers\201 has 1 Imgs
#
# Writer Writers\218 has 1 Imgs
#
# Writer Writers\219 has 1 Imgs
#
# Writer Writers\220 has 1 Imgs
#
# Writer Writers\221 has 1 Imgs
#
# Writer Writers\222 has 1 Imgs
#
# Writer Writers\223 has 1 Imgs
#
# Writer Writers\224 has 1 Imgs
#
# Writer Writers\225 has 1 Imgs
#
# Writer Writers\226 has 1 Imgs
#
# Writer Writers\227 has 1 Imgs
#
# Writer Writers\228 has 1 Imgs
#
# Writer Writers\229 has 1 Imgs
#
# Writer Writers\236 has 1 Imgs
#
# Writer Writers\238 has 1 Imgs
#
# Writer Writers\240 has 1 Imgs
#
# Writer Writers\244 has 1 Imgs
#
# Writer Writers\245 has 1 Imgs
#
# Writer Writers\249 has 1 Imgs
#
# Writer Writers\251 has 1 Imgs
#
# Writer Writers\252 has 1 Imgs
#
# Writer Writers\253 has 1 Imgs
#
# Writer Writers\255 has 1 Imgs
#
# Writer Writers\257 has 1 Imgs
#
# Writer Writers\258 has 1 Imgs
#
# Writer Writers\260 has 1 Imgs
#
# Writer Writers\261 has 1 Imgs
#
# Writer Writers\262 has 1 Imgs
#
# Writer Writers\263 has 1 Imgs
#
# Writer Writers\264 has 1 Imgs
#
# Writer Writers\265 has 1 Imgs
#
# Writer Writers\266 has 1 Imgs
#
# Writer Writers\267 has 1 Imgs
#
# Writer Writers\268 has 1 Imgs
#
# Writer Writers\269 has 1 Imgs
#
# Writer Writers\270 has 1 Imgs
#
# Writer Writers\290 has 1 Imgs
#
# Writer Writers\302 has 1 Imgs
#
# Writer Writers\303 has 1 Imgs
#
# Writer Writers\304 has 1 Imgs
#
# Writer Writers\305 has 1 Imgs
#
# Writer Writers\307 has 1 Imgs
#
# Writer Writers\308 has 1 Imgs
#
# Writer Writers\309 has 1 Imgs
#
# Writer Writers\310 has 1 Imgs
#
# Writer Writers\312 has 1 Imgs
#
# Writer Writers\313 has 1 Imgs
#
# Writer Writers\314 has 1 Imgs
#
# Writer Writers\315 has 1 Imgs
#
# Writer Writers\316 has 1 Imgs
#
# Writer Writers\317 has 1 Imgs
#
# Writer Writers\318 has 1 Imgs
#
# Writer Writers\319 has 1 Imgs
#
# Writer Writers\322 has 1 Imgs
#
# Writer Writers\323 has 1 Imgs
#
# Writer Writers\326 has 1 Imgs
#
# Writer Writers\327 has 1 Imgs
#
# Writer Writers\331 has 1 Imgs
#
# Writer Writers\359 has 1 Imgs
#
# Writer Writers\360 has 1 Imgs
#
# Writer Writers\361 has 1 Imgs
#
# Writer Writers\362 has 1 Imgs
#
# Writer Writers\363 has 1 Imgs
#
# Writer Writers\364 has 1 Imgs
#
# Writer Writers\365 has 1 Imgs
#
# Writer Writers\366 has 1 Imgs
#
# Writer Writers\367 has 1 Imgs
#
# Writer Writers\368 has 1 Imgs
#
# Writer Writers\369 has 1 Imgs
#
# Writer Writers\370 has 1 Imgs
#
# Writer Writers\371 has 1 Imgs
#
# Writer Writers\372 has 1 Imgs
#
# Writer Writers\373 has 1 Imgs
#
# Writer Writers\375 has 1 Imgs
#
# Writer Writers\376 has 1 Imgs
#
# Writer Writers\377 has 1 Imgs
#
# Writer Writers\378 has 1 Imgs
#
# Writer Writers\393 has 1 Imgs
#
# 168

# %%
def GenerateTestCases(numTest = 1):
     
    
    root = "Writers"
    Writers = [] # writers folders contains more than 3 photos
    threCount = 0
    for dirpath, dirnames, files in os.walk(os.path.join(root)):
        if dirpath == root :
            continue
    #     print(f'Found directory: {dirpath}')
        count = 0
        for file_name in files:
            count += 1
        if count > 2:
            threCount += 1 
            Writers.append(dirpath.split("\\")[1])

#     print(threCount)
    
    rootDir = "TestCases"
    try:
        os.mkdir(rootDir)
    except FileExistsError as exc:
        pass

    file1 = open(os.path.join(rootDir ,"results.txt"), "w")
    for i in range(1, 1 + numTest):    
        random.shuffle(Writers)
        selectedWriters = random.sample(Writers,3)
        path = os.path.join(rootDir,str(i))
        try:
            os.mkdir(path)
        except FileExistsError as exc:
            pass
        
        for k in range(1,4):
            try:
                os.mkdir(os.path.join(path,str(k)))
            except FileExistsError as exc:
                pass
            
        testImgs = []
         
        for num, writer in enumerate(selectedWriters,1):
            # create writer folder
            try:
                os.mkdir(os.path.join(path,str(num)))
                
            except FileExistsError as exc:
                pass
            # set src and des folder paths and get writer Images
            testCasePath = os.path.join(path,str(num))
            oldImagePath = os.path.join(root,writer)
            WriterImgs = os.listdir(oldImagePath)
            # sample 3 random Images:
            WriterImgs = random.sample(WriterImgs,3)
            # copy first 2 imgs in writer folder
            for img in WriterImgs[:2]:
                src = os.path.join(oldImagePath, img)
                dst = os.path.join(testCasePath, img)
                shutil.copy(src, dst)
            testImgs.append((num,os.path.join(oldImagePath,WriterImgs[2])))
            
            print("Writer {} imgs {} copied to {} from {}".format(writer,WriterImgs[:2],testCasePath,oldImagePath))
        # get a third random img as testcase
        testImg = random.choice(testImgs)
        src = testImg[1]
        dst = os.path.join(path, "test." +testImg[1].split(".")[1])
        shutil.copy(src, dst)
        print("Test img from writer {} at dest {} \n\n".format(testImg,dst))
        file1.write("For TestCase {} the test Img belong to writer -> {}  \n\n".format(i,testImg[0]))

    file1.close()

# %%
GenerateTestCases(5)
# Out:
# Writer 090 imgs ['b01-044.png', 'b01-049.png'] copied to TestCases\1\1 from Writers\090
# Writer 247 imgs ['e07-090.png', 'e07-079.png'] copied to TestCases\1\2 from Writers\247
# Writer 243 imgs ['e04-127.png', 'e04-119.png'] copied to TestCases\1\3 from Writers\243
# Test img from writer (1, 'Writers\\090\\b01-053.png') at dest TestCases\1\test.png
#
#
# Writer 209 imgs ['d07-102.png', 'd07-096.png'] copied to TestCases\2\1 from Writers\209
# Writer 155 imgs ['c03-021f.png', 'c03-000f.png'] copied to TestCases\2\2 from Writers\155
# Writer 247 imgs ['e07-076.png', 'e07-083.png'] copied to TestCases\2\3 from Writers\247
# Test img from writer (3, 'Writers\\247\\e07-079.png') at dest TestCases\2\test.png
#
#
# Writer 332 imgs ['g06-050a.png', 'g06-026a.png'] copied to TestCases\3\1 from Writers\332
# Writer 300 imgs ['g01-074.png', 'g01-067.png'] copied to TestCases\3\2 from Writers\300
# Writer 272 imgs ['f04-004.png', 'f04-011.png'] copied to TestCases\3\3 from Writers\272
# Test img from writer (1, 'Writers\\332\\g06-011a.png') at dest TestCases\3\test.png
#
#
# Writer 158 imgs ['c04-013.png', 'c04-008.png'] copied to TestCases\4\1 from Writers\158
# Writer 125 imgs ['c06-020.png', 'b06-008.png'] copied to TestCases\4\2 from Writers\125
# Writer 173 imgs ['d06-008.png', 'd06-020.png'] copied to TestCases\4\3 from Writers\173
# Test img from writer (3, 'Writers\\173\\c06-011.png') at dest TestCases\4\test.png
#
#
# Writer 062 imgs ['a04-066.png', 'a04-072.png'] copied to TestCases\5\1 from Writers\062
# Writer 348 imgs ['g06-042r.png', 'g06-031r.png'] copied to TestCases\5\2 from Writers\348
# Writer 061 imgs ['a04-050.png', 'a04-047.png'] copied to TestCases\5\3 from Writers\061
# Test img from writer (1, 'Writers\\062\\a04-069.png') at dest TestCases\5\test.png
